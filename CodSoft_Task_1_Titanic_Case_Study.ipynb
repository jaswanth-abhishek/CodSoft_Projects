# %%
import numpy as np
import pandas as pd

# %%
titanic_data=pd.read_csv(r"C:\Users\Home\Downloads\Titanic-Dataset.csv")

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_data.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %% [markdown]
# # Let us check the shape of the dataset (Rows and Columns)

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Age has 177 missing values, which may need handling, as it could be a significant feature for survival prediction.
#Cabin has 687 missing values, which is a large proportion of the dataset.
#Embarked has 2 missing values, a relatively small number, and you can likely impute these missing values with the most frequent value or a reasonable substitute.

# %%
#Dropped Cabin Column
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Replacing missing values in Age with mean value
titanic_data["Age"].fillna(titanic_data["Age"].mean(),inplace=True)

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Finding the mode value of embarked column

# %%
print(titanic_data["Embarked"].mode())
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
print(titanic_data["Embarked"].mode()[0])
# Out:
# S

# %%
titanic_data["Embarked"].fillna(titanic_data["Embarked"].mode()[0],inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Examining Data Analysis

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Data Visulaisation

# %%
#Let us check for survived and non survived cases using countplot

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set()

# %%
sns.countplot('Survived',data=titanic_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#Plotting the No.of Survivors as per gender

# %%
sns.countplot('Sex',data=titanic_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#comparing above 2 graphs

# %%
sns.countplot('Sex',hue="Survived",data=titanic_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot('Embarked',data=titanic_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Numerical Attributes

# %%
sns.distplot(titanic_data['Fare'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.displot(titanic_data['PassengerId'])

# %%
sns.displot(titanic_data['Age'])

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#Dropping not useful columns
titanic_data=titanic_data.drop(columns=['Name','Ticket'],axis=1)
titanic_data.head(4)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S

# %%
sns.pairplot(titanic_data,corner=True,diag_kind='kde',plot_kws={'alpha':0.6})
plt.show()

# %%
corr = titanic_data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
plt.figure(figsize=(15, 9))
sns.heatmap(corr, mask=mask, annot=True, fmt='.2f', cmap='coolwarm', cbar_kws={'shrink': .8}, linewidth=0.5, vmin=-1, vmax=1)
plt.show()

# %%
titanic_data.head(3)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S

# %%
#Categorical to Numerical for further modelling

# %%
titanic_data['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

columns_to_encode = ['Sex', 'Embarked']
label_encoder = LabelEncoder()

for feature in columns_to_encode:
    titanic_data[feature] = label_encoder.fit_transform(titanic_data[feature])

titanic_data.head(3)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2

# %%
A=titanic_data.drop(columns=['PassengerId','Survived'],axis=1)
B=titanic_data['Survived']

# %%
print(A)
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.000000      1      0   7.2500         2
# 1         1    0  38.000000      1      0  71.2833         0
# 2         3    0  26.000000      0      0   7.9250         2
# 3         1    0  35.000000      1      0  53.1000         2
# 4         3    1  35.000000      0      0   8.0500         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    1  27.000000      0      0  13.0000         2
# 887       1    0  19.000000      0      0  30.0000         2
# 888       3    0  29.699118      1      2  23.4500         2
# 889       1    1  26.000000      0      0  30.0000         0
# 890       3    1  32.000000      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
print(B)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic_data[titanic_data['Pclass'] == 1].Survived.groupby(titanic_data.Survived).count().plot(
    kind='pie', 
    figsize=(6, 6), 
    explode=[0, 0.05], 
    autopct='%1.1f%%'
)
plt.axis('equal')
plt.legend(["Perished", "Survived"])
plt.title("First class survival rate")
plt.show()

# %%
sns.barplot('Pclass','Survived',hue='Sex', data=titanic_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab([titanic_data.Sex, titanic_data.Survived], [titanic_data.SibSp, titanic_data.Pclass], margins=True)
# Out:
# SibSp           0             1          2         3          4  5  8  All
# Pclass          1    2    3   1   2   3  1  2   3  1  2   3   3  3  3
# Sex Survived
# 0   0           1    3   33   2   3  21  0  0   3  0  0   7   4  1  3   81
#     1          48   41   48  38  25  17  3  3   4  2  1   1   2  0  0  233
# 1   0          59   67  235  16  20  35  1  4   7  1  0   4  11  4  4  468
#     1          29    9   35  15   7  10  1  1   1  0  0   0   1  0  0  109
# All           137  120  351  71  55  83  5  8  15  3  1  12  18  5  7  891

# %%
#The above crosstab indicates 2 things:

#Most of the passerenges didn'y had siblings onboard and the majority had atmost 1 sibling onboard

#Not much of priority was given to the passengers who had sibelings onboard in the rescue operation

# %%
pd.crosstab([titanic_data.Sex, titanic_data.Survived], [titanic_data.Parch, titanic_data.Pclass], margins=True)
# Out:
# Parch           0             1           2          3     4     5  6  All
# Pclass          1    2    3   1   2   3   1   2   3  2  3  1  3  3  3
# Sex Survived
# 0   0           1    5   35   0   1  13   2   0  17  0  1  0  2  3  1   81
#     1          63   40   50  17  17  12  11  11   8  2  1  0  0  1  0  233
# 1   0          63   81  260  10   7  22   3   3  15  0  1  1  1  1  0  468
#     1          36    8   36   4   7   8   5   2   3  0  0  0  0  0  0  109
# All           163  134  381  31  32  55  21  16  43  2  3  1  3  5  1  891

# %%
#The above crosstab indicates 2 things:

#Most of the passerenges didn't had parents onboard and the majority had atmost 1 parent onboard
#Not much of priority was given to the passengers who had parents onboard in the rescue operation

# %%
if 'Name' in titanic_data.columns:
    sns.pairplot(titanic_data.drop("Name", axis=1).dropna(), hue="Survived")
else:
    sns.pairplot(titanic_data.dropna(), hue="Survived")

# %%
#The correlation table didn’t provide much insight.

#Now, let's focus on addressing the missing values in the Age column.

#One way is to fill the missing values with the mean value: titanic_data.fillna(value = titanic_data.mean())
#Alternatively, we can fill the missing values with the mean for each corresponding Survived category
